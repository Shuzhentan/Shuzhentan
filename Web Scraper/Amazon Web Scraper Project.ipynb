# %%
#reference:https://github.com/AlexTheAnalyst/PortfolioProjects/blob/main/Amazon%20Web%20Scraper%20Project.ipynb
from bs4 import BeautifulSoup
import requests
import time
import datetime 
import smtplib

# %%
# connect to website
URL = 'https://www.amazon.com/Hanes-Womens-Nano-T-V-Neck-T-Shirt/dp/B071XB2LDV/ref=sr_1_37?c=ts&keywords=Women%27s+Novelty+Tops+%26+Tees&qid=1661952888&s=apparel&sr=1-37&ts_id=9056922011'

# obtain user agent from httpbin.org/get
headers: {
   "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8", 
   "Accept-Encoding": "gzip, deflate", 
   "Accept-Language": "en-US,en;q=0.5", 
   "Host": "httpbin.org", 
   "Upgrade-Insecure-Requests": "1", 
   "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:104.0) Gecko/20100101 Firefox/104.0",
   "X-Amzn-Trace-Id": "Root=1-630f5f08-1028b31f086695af7f8ff135"
  } 

# bring in the data
page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser") #html of the website

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

title = soup2.find(id='productTitle').get_text()

price = soup2.find(id='priceblock_ourprice').get_text()

#print(soup1)
#print(soup2)
#print(title)
#print(price)

#try puling ratings
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>ERROR: The request could not be satisfied</title>
# </head><body>
# <h1>403 ERROR</h1>
# <h2>The request could not be satisfied.</h2>
# <hr noshade="" size="1px"/>
# Bad request.
# We can't connect to the server for this app or website at this time. There might be too much traffic or a configuration error. Try again later, or contact the app or website owner.
# <br clear="all"/>
# If you provide content to customers through CloudFront, you can find steps to troubleshoot and help prevent this error by reviewing the CloudFront documentation.
# <br clear="all"/>
# <hr noshade="" size="1px"/>
# <pre>
# Generated by cloudfront (CloudFront)
# Request ID: 54tnFWV_uvmNTmeGaEBscwhxQYeD-beLbxaQYzCXCZ-iWFCugmE2XQ==
# </pre>
# <address>
# </address>
# </body></html>

# %%
price = price.strip()[1:]
title = title.strip()

print(price)
print(title)
type(price) # returns datatype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 price = price.strip()[1:]
#       2 title = title.strip()
#       4 print(price)
#
# NameError: name 'price' is not defined

# %%
import datetime

today = datetime.date.today()
print(today)
# Out:
# 2022-08-31

# %%
import csv

header = ['Title', 'Price', 'Date']
data = [title, price, today]

type(data) # returnd list

# Think twice before running this!
with open('AmazonWebScraperDataset.csv','w',newline='',
         encodind='UTF8') as f:  #open the file in the write mode, 
                                 #newline='' removes the black line
    writer = csv.writer(f) #create the csv writer
    writer.writerow(header) #insert header row
    writer.writerow(data) #insert data row
#Note: If you ever want to run the program again without delete the previous data
#don't run this function!

#Reference: https://www.pythontutorial.net/python-basics/python-write-csv-file/
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [47], in <cell line: 4>()
#       1 import csv
#       3 header = ['Title', 'Price']
# ----> 4 data = [title, price]
#       6 type(data) # returnd list
#       8 with open('AmazonWebScraperDataset.csv','w',newline='',
#       9          encodind='UTF8') as f:  #open the file in the write mode,
#      10                                  #newline='' removes the black line
#
# NameError: name 'title' is not defined

# %%
import pandas as pd

df = pd.read_csv()

df

# %%
# append data to the csv

with open('AmazonWebScraperDataset.csv','w',newline='',
         encodind='UTF8') as f:  # replace "w" with "a+"; "a+":appending
    writer = csv.writer(f) 
    writer.writerow(data)

# %%
# make reference: https://automatetheboringstuff.com/2e/chapter18/
def send_mail():
    server=smtplib.SMTP_SSL('smtp.gmail.com', 465)
    server.ehlo()
    server.login('zhen1624_@hotmail.com', 'typeinyourpassword')
    
    subject=' '
    body=' '
    
    msg=f'Subject={subject}\n\n{body}'
    
    server.sendmail(
        'zhen1624_@hotmail.com',
        msg
    )

# %%
def check_price():
    # connect to website
    URL = 'https://www.amazon.com/Hanes-Womens-Nano-T-V-Neck-T-Shirt/dp/B071XB2LDV/ref=sr_1_37?c=ts&keywords=Women%27s+Novelty+Tops+%26+Tees&qid=1661952888&s=apparel&sr=1-37&ts_id=9056922011'

# obtain user agent from httpbin.org/get
    headers: {
       "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8", 
       "Accept-Encoding": "gzip, deflate", 
       "Accept-Language": "en-US,en;q=0.5", 
       "Host": "httpbin.org", 
       "Upgrade-Insecure-Requests": "1", 
       "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:104.0) Gecko/20100101 Firefox/104.0",
       "X-Amzn-Trace-Id": "Root=1-630f5f08-1028b31f086695af7f8ff135"
      } 

    # bring in the data
    page = requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser") #html of the website

    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

    title = soup2.find(id='productTitle').get_text()
    price = soup2.find(id='priceblock_ourprice').get_text()

    price = price.strip()[1:]
    title = title.strip()

    import datetime

    today = datetime.date.today()

    import csv

    header = ['Title', 'Price', 'Date']
    data = [title, price, today]

    with open('AmazonWebScraperDataset.csv','w',newline='',
             encodind='UTF8') as f:  # replace "w" with "a+"; "a+":appending
        writer = csv.writer(f) 
        writer.writerow(data) 
        
    # when the price is lower than a certain value, send me an email
    if(price<14):
        send_mail()

# %%
while(True):
    check_price()
    time.sleep(5) # run the function evert 5 seconds
#click the button 'interrupt the kernel' to stop the automation

# %%
import pandas as pd

df = pd.read_csv()

df
